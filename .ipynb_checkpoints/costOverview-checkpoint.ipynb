# %%
from validator.InstanceCO22 import InstanceCO22
from util import *
import pandas as pd

# %%
res = []
for i in range(1,31):
    inst  = loadInstance(i)
    res.append({
        'TRUCK_DISTANCE_COST': inst.TruckDistanceCost,
        'TRUCK_DAY_COST': inst.TruckDayCost,
        'TRUCK_COST':inst.TruckCost,
        'VAN_DISTANCE_COST':inst.VanDistanceCost,
        'VAN_DAY_COST':inst.VanDayCost,
        'VAN_COST':inst.VanCost,
        'DELIVER_EARLY_PENALTY':inst.deliverEarlyPenalty
        })
df = pd.DataFrame(res, index= list(range(1,31)))

# %%
df
# Out:
#     TRUCK_DISTANCE_COST  TRUCK_DAY_COST  TRUCK_COST  VAN_DISTANCE_COST  \
# 1                    20             200           0                 10
# 2                    20             200           0                 10
# 3                    20             200           0                 10
# 4                    20             200           0                 10
# 5                    20             200           0                 10
# 6                    20             200      100000                 10
# 7                    20             200           0                  1
# 8                    20             200           0                 10
# 9                    20             200           0                 10
# 10                   20            2000           0                 10
# 11                   20             200           0                 10
# 12                   20             200           0                 10
# ...
